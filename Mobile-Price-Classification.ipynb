# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
df=pd.read_csv('cellphones data.csv')

# %%
df
# Out:
#     cellphone_id     brand                 model operating system  \
# 0              0     Apple      iPhone SE (2022)              iOS
# 1              1     Apple        iPhone 13 Mini              iOS
# 2              2     Apple             iPhone 13              iOS
# 3              3     Apple         iPhone 13 Pro              iOS
# 4              4     Apple     iPhone 13 Pro Max              iOS
# 5              5     Apple             iPhone XR              iOS
# 6              6      Asus             Zenfone 8          Android
# 7              7   Samsung            Galaxy A13          Android
# 8              8   Samsung            Galaxy A32          Android
# 9              9   Samsung            Galaxy A53          Android
# 10            10   Samsung            Galaxy S22          Android
# 11            11   Samsung       Galaxy S22 Plus          Android
# 12            12   Samsung      Galaxy S22 Ultra          Android
# ...

# %%
df.shape
# Out:
# (33, 14)

# %%
df.isnull().sum()
# Out:
# cellphone_id        0
# brand               0
# model               0
# operating system    0
# internal memory     0
# RAM                 0
# performance         0
# main camera         0
# selfie camera       0
# battery size        0
# screen size         0
# weight              0
# price               0
# release date        0
# dtype: int64

# %%
df.drop(columns=['cellphone_id'],inplace=True)

# %%
df.drop(columns=['release date'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             33 non-null     object
#  1   model             33 non-null     object
#  2   operating system  33 non-null     object
#  3   internal memory   33 non-null     int64
#  4   RAM               33 non-null     int64
#  5   performance       33 non-null     float64
#  6   main camera       33 non-null     int64
#  7   selfie camera     33 non-null     int64
#  8   battery size      33 non-null     int64
#  9   screen size       33 non-null     float64
#  10  weight            33 non-null     int64
#  11  price             33 non-null     int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 3.2+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        internal memory        RAM  performance  main camera  selfie camera  \
# count        33.000000  33.000000    33.000000    33.000000      33.000000
# mean        148.363636   6.787879     6.219091    41.333333      15.484848
# std          92.197417   2.712904     2.885472    26.350601      10.028463
# min          32.000000   3.000000     1.020000    12.000000       4.000000
# 25%         128.000000   4.000000     3.800000    12.000000       8.000000
# 50%         128.000000   8.000000     6.880000    50.000000      12.000000
# 75%         128.000000   8.000000     7.940000    50.000000      16.000000
# max         512.000000  12.000000    11.000000   108.000000      40.000000
#
#        battery size  screen size      weight        price
# count     33.000000    33.000000   33.000000    33.000000
# mean    4320.666667     6.433333  197.363636   628.272727
# std      818.746590     0.476095   25.379394   433.873057
# min     2018.000000     4.700000  141.000000   129.000000
# ...

# %%
sns.barplot(data=df,x='brand',y='price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df['model'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='model'>

# %%
sns.barplot(data=df,x='model',y='price')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['screen size'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9812\1780825808.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['screen size'])
# <Axes: xlabel='screen size', ylabel='Density'>

# %%
sns.barplot(data=df,x='screen size',y='price')
plt.xticks(rotation='vertical')
plt.title("How price vary with Screen Size")
plt.show()

# %%
sns.scatterplot(data=df,x='screen size',y='price')
# Out:
# <Axes: xlabel='screen size', ylabel='price'>

# %%
df.columns
# Out:
# Index(['brand', 'model', 'operating system', 'internal memory', 'RAM',
#        'performance', 'main camera', 'selfie camera', 'battery size',
#        'screen size', 'weight', 'price'],
#       dtype='object')

# %%
sns.barplot(data=df,x='RAM',y='performance')
plt.xticks(rotation='vertical')
plt.title("Correlation between Ram and Performance")
plt.show()

# %%
sns.barplot(data=df,x='brand',y='performance')
plt.xticks(rotation='vertical')
plt.title("Brands with highest performance")
plt.show()

# %%
df.corr(numeric_only=True)['price']
# Out:
# internal memory    0.834266
# RAM                0.706235
# performance        0.527611
# main camera       -0.255498
# selfie camera      0.023828
# battery size      -0.134425
# screen size        0.316986
# weight             0.546797
# price              1.000000
# Name: price, dtype: float64

# %%
sns.barplot(data=df,x='brand',y='price')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.plot(kind='box', subplots=True, figsize=(20,20), layout=(5,5))
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df.corr(numeric_only=True) , annot = True, cmap= "Greens")
# Out:
# <Axes: >

# %%
df['RAM'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RAM'>

# %%
sns.barplot(data=df,x='RAM',y='price')
# Out:
# <Axes: xlabel='RAM', ylabel='price'>

# %%
df['internal memory'].value_counts()
# Out:
# internal memory
# 128    20
# 256     6
# 64      3
# 32      3
# 512     1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['brand', 'model', 'operating system', 'internal memory', 'RAM',
#        'performance', 'main camera', 'selfie camera', 'battery size',
#        'screen size', 'weight', 'price'],
#       dtype='object')

# %%
df['operating system'].value_counts()
# Out:
# operating system
# Android    27
# iOS         6
# Name: count, dtype: int64

# %%
sns.barplot(data=df,x='operating system',y='price')
# Out:
# <Axes: xlabel='operating system', ylabel='price'>

# %%
sns.distplot(df['weight'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9812\3941653390.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['weight'])
# <Axes: xlabel='weight', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('price',axis=1),df['price'],test_size=0.3,random_state=0)

# %%
x_train
# Out:
#        brand                 model operating system  internal memory  RAM  \
# 29  Motorola  Moto G Stylus (2022)          Android              128    6
# 23      Vivo               X80 Pro          Android              256    8
# 15    Google             Pixel 6            Android              128    8
# 8    Samsung            Galaxy A32          Android               64    4
# 13   Samsung       Galaxy Z Flip 3          Android              128    8
# 30  Motorola    Moto G Play (2021)          Android               32    3
# 5      Apple             iPhone XR              iOS               64    3
# 14   Samsung       Galaxy Z Fold 3          Android              256   12
# 28      Sony            Xperia Pro          Android              512   12
# 22      Oppo           Find X5 Pro          Android              256   12
# 1      Apple        iPhone 13 Mini              iOS              128    4
# 12   Samsung      Galaxy S22 Ultra          Android              128    8
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,2])
],remainder='passthrough')

step2=LinearRegression()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

print('R2 Score',r2_score(y_test,y_pred))
print('MEA',mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.21261531536379963
# MEA 153.21623691537596
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
